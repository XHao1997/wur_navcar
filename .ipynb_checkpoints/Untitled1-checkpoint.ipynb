# %%
import ultralytics
import matplotlib.pyplot as plt

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("weights/block.pt")  # load a custom model

# %%
result = model('data/rgb/rgb_01.jpg')
# Out:
# image 1/1 C:\Users\Hao Xu\Desktop\wur_navcar\data\rgb\rgb_01.jpg: 480x640 1 block, 267.5ms
# Speed: 3.0ms preprocess, 267.5ms inference, 1739.3ms postprocess per image at shape (1, 3, 480, 640)

# %%
mask = result[0].masks.data

# %%
imgs = mask.numpy()

# %%
imgs = imgs.transpose(1,2,0)

# %%
imgs
