# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
rgb_img = cv2.imread('test_img/rgb.jpg')
depth_img = cv2.imread('test_img/depth2.png',cv2.IMREAD_UNCHANGED)

# %%
plt.subplots(1,2)
plt.subplot(1,2,1)
plt.imshow(rgb_img[:,:,::-1])
plt.subplot(1,2,2)
plt.imshow(depth_img)

# %%
class camera():
    def __init__(self):
        self.ir_intrinsic_matrix = np.array(
            [[590.148060671712, 0, 331.776762806745],
             [0, 586.145968930385, 230.802770705792], [0, 0, 1]])
        self.ir_distortion_matrix = np.array([-0.1093, 0.2668, 0, 0, 0])
        self.rgb_intrinsic_matrix = np.array(
            [[539.020832787886, 0, 325.629602617091],
             [0, 534.861253579807, 256.726953726026], [0, 0, 1]])
        self.rgb_distortion_matrix = np.array(
            [0.147555317189259, -0.303342952312001, 0, 0, 0])
        self.R = np.array(
            [[0.999980636769351, -0.006120529301233, -0.001124814400937],
             [0.006107544444555, 0.999918558578594, -0.011205985497267],
             [0.001193309357038, 0.011198898659239, 0.999936578329645]])
        self.A = np.array([[1, 0, 0, -25.96], [0, 1, 0, -0.9825],
                           [0, 0, 1, 4.4076], [0, 0, 0, 1]])
        self.ir_rgb_extrinsic = np.array([[
            0.999980636769351, -0.00612052930123339, -0.00112481440093692,
            -25.9592777097289
        ],
                                          [
                                              0.00610754444455511,
                                              0.999918558578594,
                                              -0.0112059854972665,
                                              -0.982453053169550
                                          ],
                                          [
                                              0.00119330935703847,
                                              0.0111988986592391,
                                              0.999936578329645,
                                              4.40757685764124
                                          ], [0, 0, 0, 1]])
        img_size = (640, 480)
        return

    def rectify(self):

        return

    def undistortion(self, distorted_img, camera_type):
        # Correcting the distortion
        if camera_type == 'rgb':
            undistorted_img = cv2.undistort(
                distorted_img, self.rgb_intrinsic_matrix,
                self.rgb_distortion_matrix)  # Correcting the distortion
        elif camera_type == 'ir':
            undistorted_img = cv2.undistort(
                distorted_img, self.ir_intrinsic_matrix,
                self.ir_distortion_matrix)  # Correcting the distortion
        return undistorted_img

# %%
np.array([[
    0.999980636769351, -0.00612052930123339, -0.00112481440093692,
    -25.9592777097289
],
          [
              0.00610754444455511, 0.999918558578594, -0.0112059854972665,
              -0.982453053169550
          ],
          [
              0.00119330935703847, 0.0111988986592391, 0.999936578329645,
              4.40757685764124
          ], [0, 0, 0, 1]])
# Out:
# array([[ 9.99980637e-01, -6.12052930e-03, -1.12481440e-03,
#         -2.59592777e+01],
#        [ 6.10754444e-03,  9.99918559e-01, -1.12059855e-02,
#         -9.82453053e-01],
#        [ 1.19330936e-03,  1.11988987e-02,  9.99936578e-01,
#          4.40757686e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00]])

# %%
kinect = camera()

# %%
undistorted_depth_img.shape
# Out:
# (480, 640)

# %%
undistorted_rgb_img = kinect.undistortion(rgb_img,'rgb')
plt.imshow( undistorted_rgb_img[:,:,::-1])
plt.show()
undistorted_depth_img = kinect.undistortion(depth_img,'ir')
plt.imshow( undistorted_depth_img[:,:])
plt.show()

# %%
np.unique(depth_img)
dist = 0.075*585/(1090-depth_img)*8
dist
# Out:
# array([[1.84736842, 1.84736842, 1.85714286, ..., 0.0054352 , 0.0054352 ,
#         0.0054352 ],
#        [1.85714286, 1.85714286, 1.86702128, ..., 0.0054352 , 0.0054352 ,
#         0.0054352 ],
#        [1.85714286, 1.85714286, 1.86702128, ..., 0.0054352 , 0.0054352 ,
#         0.0054352 ],
#        ...,
#        [0.0054352 , 0.0054352 , 0.0054352 , ..., 0.0054352 , 0.0054352 ,
#         0.0054352 ],
#        [0.0054352 , 0.0054352 , 0.0054352 , ..., 0.0054352 , 0.0054352 ,
#         0.0054352 ],
#        [0.0054352 , 0.0054352 , 0.0054352 , ..., 0.0054352 , 0.0054352 ,
#         0.0054352 ]])

# %%
# Step 2: Transform to RGB camera frame
points_3d_rgb = np.dot(extrinsic_matrix, points_3d_depth.reshape(-1, 3).T).T

# Step 3: Project onto RGB image plane
points_2d_rgb = cv2.projectPoints(points_3d_rgb.reshape(-1, 1, 3), 
                                  (0, 0, 0), (0, 0, 0), 
                                  intrinsic_matrix_rgb, 
                                  distCoeffs=None)[0]# Step 1: Convert depth image to 3D points in depth camera frame
points_3d_depth = cv2.reprojectImageTo3D(depth_image, intrinsic_matrix_depth)

# Step 2: Transform to RGB camera frame
points_3d_rgb = np.dot(extrinsic_matrix, points_3d_depth.reshape(-1, 3).T).T

# Step 3: Project onto RGB image plane
points_2d_rgb = cv2.projectPoints(points_3d_rgb.reshape(-1, 1, 3), 
                                  (0, 0, 0), (0, 0, 0), 
                                  intrinsic_matrix_rgb, 
                                  distCoeffs=None)[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[482], line 2
#       1 # Step 2: Transform to RGB camera frame
# ----> 2 points_3d_rgb = np.dot(extrinsic_matrix, points_3d_depth.reshape(-1, 3).T).T
#       4 # Step 3: Project onto RGB image plane
#       5 points_2d_rgb = cv2.projectPoints(points_3d_rgb.reshape(-1, 1, 3),
#       6                                   (0, 0, 0), (0, 0, 0),
#       7                                   intrinsic_matrix_rgb,
#       8                                   distCoeffs=None)[0]# Step 1: Convert depth image to 3D points in depth camera frame
#
# NameError: name 'extrinsic_matrix' is not defined

# %%
cx_ir = kinect.ir_intrinsic_matrix[0,2]
cy_ir = kinect.ir_intrinsic_matrix[1,2]
fx_ir = kinect.ir_intrinsic_matrix[0,0]
fy_ir = kinect.ir_intrinsic_matrix[1,1]

# %%
def pixel2world(x,y,intrinsic_matrix, dist):
    cx = intrinsic_matrix[0,2]
    cy = intrinsic_matrix[1,2]
    fx = intrinsic_matrix[0,0]
    fy = intrinsic_matrix[1,1]
    Z = dist[x,y]
    X = (x - cx) * Z / fx
    Y = (y - cy) * Z / fy
    return X, Y ,Z

# %%
depth_img.shape
# Out:
# (480, 640)

# %%
x.shape
# Out:
# (640, 480)

# %%
x = np.tile(np.arange(480), (640, 1))

# %%
y = np.tile(np.arange(640).reshape(-1, 1), (1, 480))

# %%
X,Y,Z = pixel2world(x,y,kinect.ir_intrinsic_matrix, dist)

# %%
points_3d = np.dstack((Y, X, Z))

# %%
points_3d=points_3d.reshape(-1,3)

# %%
import open3d as o3d
import numpy as np

# Let's say 'points_3d' is your array of 3D points (numpy array)
# points_3d.shape should be (N, 3), where N is the number of points

# Create an Open3D point cloud object
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points_3d.astype(np.float64))

# Visualize the point cloud
o3d.visualization.draw_geometries([pcd])
# Out:
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.

# %%
points_3d
# Out:
# array([[-7.27425885e-01, -1.03857651e+00,  1.84736842e+00],
#        [-7.31274699e-01, -1.04092472e+00,  1.85714286e+00],
#        [-7.31274699e-01, -1.03777781e+00,  1.85714286e+00],
#        ...,
#        [ 3.78512364e-03,  1.33749119e-03,  5.43520339e-03],
#        [ 3.78512364e-03,  1.34670109e-03,  5.43520339e-03],
#        [ 3.78512364e-03,  1.35591099e-03,  5.43520339e-03]])

# %%
points_3d = np.append(points_3d.T, np.ones((1,points_3d.shape[0])),axis=0)

# %%
kinect.A.dot(points_3d).T
# Out:
# array([[-26.68742588,  -2.02107651,   6.25496842,   1.        ],
#        [-26.6912747 ,  -2.02342472,   6.26474286,   1.        ],
#        [-26.6912747 ,  -2.02027781,   6.26474286,   1.        ],
#        ...,
#        [-25.95621488,  -0.98116251,   4.4130352 ,   1.        ],
#        [-25.95621488,  -0.9811533 ,   4.4130352 ,   1.        ],
#        [-25.95621488,  -0.98114409,   4.4130352 ,   1.        ]])

# %%
points_3d.T
# Out:
# array([[-7.27425885e-01, -1.03857651e+00,  1.84736842e+00,
#          1.00000000e+00],
#        [-7.31274699e-01, -1.04092472e+00,  1.85714286e+00,
#          1.00000000e+00],
#        [-7.31274699e-01, -1.03777781e+00,  1.85714286e+00,
#          1.00000000e+00],
#        ...,
#        [ 3.78512364e-03,  1.33749119e-03,  5.43520339e-03,
#          1.00000000e+00],
#        [ 3.78512364e-03,  1.34670109e-03,  5.43520339e-03,
#          1.00000000e+00],
#        [ 3.78512364e-03,  1.35591099e-03,  5.43520339e-03,
#          1.00000000e+00]])

# %%
rgb_intrinsic_matrix = np.zeros((4,4))
rgb_intrinsic_matrix[:3,:3] = kinect.rgb_intrinsic_matrix
rgb_intrinsic_matrix[3,3] = 1
P = kinect.A.dot(rgb_intrinsic_matrix)

# %%
P
# Out:
# array([[539.02083279,   0.        , 325.62960262, -25.96      ],
#        [  0.        , 534.86125358, 256.72695373,  -0.9825    ],
#        [  0.        ,   0.        ,   1.        ,   4.4076    ],
#        [  0.        ,   0.        ,   0.        ,   1.        ]])

# %%
np.unique(P.dot(points_3d).astype(int)[0,:])
# Out:
# array([ -25,  -23,  -22, ..., 4715, 4731, 4739])

# %%
points_3d.shape
# Out:
# (4, 307200)
